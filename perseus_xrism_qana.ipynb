# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

f = fits.open("/Users/keitatanaka/Downloads/xa_merged_p0px1000_Hp.pi.gz")

exposure = f[0].header["EXPOSURE"]
f.info()
f[1].header
channel = f[1].data["CHANNEL"]
energy = channel/2000
cnt = f[1].data["COUNTS"]
# NGC 1275 z=0.017284
z=0.017284
emin = 6.5/(1+z)
emax = 6.8/(1+z)
plt.step(energy, cnt)
plt.xlim(emin, emax)
mask = (energy > emin) & (energy < emax)
cnt_100ks = np.sum(cnt[mask])
print(exposure)
print(cnt_100ks)
# 6.5-8.0 38220 cnt
# 6.5-6.8 17976 cnt
# Out:
# Filename: /Users/keitatanaka/Downloads/xa_merged_p0px1000_Hp.pi.gz
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    1260   ()
#   1  SPECTRUM      1 BinTableHDU   1296   60000R x 2C   [J, J]
#   2  GTI           1 BinTableHDU     51   41R x 2C   [1D, 1D]
# 100325.905108273
# 17976
