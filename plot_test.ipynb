# %%
from xspec import *
import os

os.chdir("/Users/keitatanaka/Dropbox/SSD_backup/PKS_XRISM/repro/mxs_scott/center_outer_all")
Xset.restore("ssm_test.xcm")
# Out:
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
#
# 1 spectrum  in use
#
# Spectral Data File: 1000_center_merged_b1.pi  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  1.797e-01 +/- 2.901e-03
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-1582
#   Telescope: XRISM Instrument: RESOLVE  Channel Type: PI
#   Exposure Time: 2.135e+04 sec
#  Using fit statistic: cstat
#  Using Response (RMF) File            1000_center_L_without_Lp.rmf for Source 1
#
# Response successfully loaded.
# Response successfully loaded.
# Response successfully loaded.
# ***Warning: Detected response matrix energy bin value = 0 (or neg).
#      XSPEC will instead use small finite value (response file will not be altered).
# Response successfully loaded.
# ...

# %%
import matplotlib.pyplot as plt

mod = AllModels(1)
print(mod)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 mod = AllModels(1)
#       4 print(mod)
#
# NameError: name 'AllModels' is not defined
